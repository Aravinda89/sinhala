# %%
import pytesseract
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img_path = '../data/img1.jpg'

image = mpimg.imread(img_path)  
plt.imshow(image)
plt.axis("off") 
plt.show()

# %%
print(pytesseract.image_to_string(Image.open(img_path), lang='sin+eng'))
# Out:
# අහිමි නුඹ
#
# පාලු ජීවිතේ තනිය මකන්නට දවසක්‌ ඔබ මට හම්‌
# අඳුරු මාවතේ අත්වැල්‌ බැඳගෙන අප දෙදෙනා පියම්න්‌ කෙරුවා
# කිසිදා නොමැකෙන මතකේ රැඳිලා ඔබ මා හැරදා වෙන්වූවා
# ඔබටම උරුම මගේම සිහිනය ඔබගේ අහසේ ලියවේවා
#
# එව්දන්‌ කියවා ඕය දෑසට්‌ යලි මා නෙත්‌ පමණක්‌ හමුවේවා.
