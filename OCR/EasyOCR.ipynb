# %%
import easyocr

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
reader = easyocr.Reader(['ta'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# -------------------------------------------------
# RuntimeError    Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 reader = easyocr.Reader(['ta'], gpu=False)
#
# File ~\anaconda3\envs\nextchat\Lib\site-packages\easyocr\easyocr.py:231, in Reader.__init__(self, lang_list, gpu, model_storage_directory, user_network_directory, detect_network, recog_network, download_enabled, detector, recognizer, verbose, quantize, cudnn_benchmark)
#     229 else:
#     230     network_params = recog_config['network_params']
# --> 231 self.recognizer, self.converter = get_recognizer(recog_network, network_params,\
#     232                                              self.character, separator_list,\
#     233                                              dict_list, model_path, device = self.device, quantize=quantize)
#
# File ~\anaconda3\envs\nextchat\Lib\site-packages\easyocr\recognition.py:174, in get_recognizer(recog_network, network_params, character, separator_list, dict_list, model_path, device, quantize)
#     172     new_key = key[7:]
#     173     new_state_dict[new_key] = value
# --> 174 model.load_state_dict(new_state_dict)
#     175 if quantize:
#     176     try:
#
# File ~\anaconda3\envs\nextchat\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Model:
# 	size mismatch for Prediction.weight: copying a param with shape torch.Size([143, 512]) from checkpoint, the shape in current model is torch.Size([127, 512]).
# 	size mismatch for Prediction.bias: copying a param with shape torch.Size([143]) from checkpoint, the shape in current model is torch.Size([127]).

# %%
img_path = '../data/img2.jpg'

image = mpimg.imread(img_path)  
plt.imshow(image)
plt.axis("off") 
plt.show()

# %%
result = reader.readtext(img_path, detail = 0)

# %%
result
# Out:
# ['85600r @60185(1 Opilqullou',
#  '2_Gotgo1g0t BsiTGuoT (@LWngi-_',
#  '86or@u ?_6or6o160T LJITIj8585',
#  '06o6oteg1ewu',
#  '91816T6oTG@m?22',
#  '8( Dioit B1T6or 5L858 8Glu_',
#  '8L646fLW G81_85MD 6u01 5u',
#  '6orgoflLW GUB W B(5600T[5u8560610 6IL',
#  '06o60r8g18681T600Tlq(58(0',
#  '$l6o6or64856ir B1T681 948181',
#  '06u(8( 951 qumuumi',
#  '6T60166 L_Glw $ 6T6oT@UW',
#  'Dgwnusl',
#  '@lrpgrunuuuq']
